# %% [raw]
# ---
# title: "A1: Exercise"
# author: "최규빈"
# date: "01/01/2025"
# draft: false
# freeze: false
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/guebin/DL2025/blob/main/posts/exercise.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" style="text-align: left"></a>

# %% [markdown]
# > 문제풀이에 필요한 모듈은 스스로 `import` 할 것

# %% [markdown]
# ## `$` 벡터와 행렬

# %% [markdown]
# `#`. 아래와 같이 length 5 인 vector를 `torch.tensor`로 선언하는 코드를 작성하라.
#
# $${\bf x} = [1,2,3,4,5]$$

# %% [markdown]
# `(풀이)`

# %%
torch.tensor([1,2,3,4,5])
# Out:
# tensor([1, 2, 3, 4, 5])

# %% [markdown]
# `#`. 아래와 같은 2x2 matrix 를 `torch.tensor`로 선언하는 코드를 작성하라.

# %% [markdown]
# $${\bf A} = \begin{bmatrix} 1 & 2 \\ 3 & 4 \end{bmatrix}$$

# %% [markdown]
# `#`.
